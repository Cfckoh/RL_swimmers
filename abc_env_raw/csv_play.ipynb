# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
losses=np.genfromtxt('csv/loss_phi=0.7.csv', delimiter=',')
rewards=np.genfromtxt('csv/rewards_phi=0.7.csv', delimiter=',')
losses2=np.genfromtxt('csv/loss_phi=0.8.csv', delimiter=',')
rewards2=np.genfromtxt('csv/rewards_phi=0.8.csv', delimiter=',')

# %%
plt.plot(rewards[60:])

# %%
len(losses)*60/150
# Out:
# 12000.0

# %%
plt.plot(losses[int(len(losses)*60/150):])

# %%
plt.plot(losses)

# %%
plt.plot(rewards2[60:])

# %%
plt.plot(losses2)
